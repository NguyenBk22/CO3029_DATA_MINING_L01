# %%
# CÀI ĐẶT THƯ VIỆN CẦN THIẾT
# !pip install mlxtend

# IMPORT THƯ VIỆN
from mlxtend.frequent_patterns import apriori, association_rules
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import numpy as np
import time
# Out:
# Requirement already satisfied: mlxtend in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.16.2)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (2.0.2)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.7.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (3.10.7)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\tgdd-asus\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\TGDD-ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\TGDD-ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\TGDD-ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# ĐỌC DỮ LIỆU NHỊ PHÂN SAU TIỀN XỬ LÝ
basket_sets = pd.read_csv("..\cleaned_basket.csv", index_col=0)

# ÁP DỤNG THUẬT TOÁN APRIORI
frequent_itemsets = apriori(basket_sets, min_support=0.01, use_colnames=True, low_memory=True)

# HIỂN THỊ CÁC TẬP MỤC PHỔ BIẾN
print(frequent_itemsets.sort_values(by='support', ascending=False).head(10))


rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)
rules = rules[(rules['confidence'] >= 0.5) & (rules['lift'] >= 1.0)]

# Sắp xếp theo độ nâng giảm dần
rules = rules.sort_values(by='lift', ascending=False)

# Hiển thị top 10 luật kết hợp mạnh nhất
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].head(10))
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\c'
# <>:2: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\TGDD-ASUS\AppData\Local\Temp\ipykernel_9936\279029203.py:2: SyntaxWarning: invalid escape sequence '\c'
#   basket_sets = pd.read_csv("..\cleaned_basket.csv", index_col=0)
# c:\Users\TGDD-ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#       support                              itemsets
# 583  0.113160  (white hanging heart t-light holder)
# 249  0.086912             (jumbo bag red retrospot)
# 413  0.084690            (regency cakestand 3 tier)
# 37   0.078083       (assorted colour bird ornament)
# 340  0.077542                       (party bunting)
# 284  0.067271             (lunch bag red retrospot)
# 467  0.060484    (set of 3 cake tins pantry design)
# 276  0.059823             (lunch bag  black skull.)
# 334  0.056760      (paper chain kit 50's christmas)
# 307  0.056340      (natural slate heart chalkboard)
#                                antecedents  \
# 149                 (herb marker rosemary)
# 148                    (herb marker thyme)
# 532              (regency tea plate green)
# 533              (regency tea plate roses)
# 511         (poppy's playhouse livingroom)
# 510            (poppy's playhouse bedroom)
# 554     (set of 3 wooden tree decorations)
# 555  (set of 3 wooden stocking decoration)
# 512         (poppy's playhouse livingroom)
# 513            (poppy's playhouse kitchen)
#
#                                consequents   support  confidence       lift
# 149                    (herb marker thyme)  0.010151    0.933702  86.844687
# 148                 (herb marker rosemary)  0.010151    0.944134  86.844687
# 532              (regency tea plate roses)  0.011532    0.845815  52.939750
# 533              (regency tea plate green)  0.011532    0.721805  52.939750
# 511            (poppy's playhouse bedroom)  0.010151    0.808612  51.779187
# 510         (poppy's playhouse livingroom)  0.010151    0.650000  51.779187
# 554  (set of 3 wooden stocking decoration)  0.010331    0.751092  50.220585
# 555     (set of 3 wooden tree decorations)  0.010331    0.690763  50.220585
# 512            (poppy's playhouse kitchen)  0.010691    0.851675  49.234483
# 513         (poppy's playhouse livingroom)  0.010691    0.618056  49.234483

# %%
plt.figure(figsize=(8,6))
plt.scatter(rules['support'], rules['confidence'], alpha=0.6, c=rules['lift'], cmap='viridis')
plt.title('Correlation chart between Support, Confidence and Lift')
plt.xlabel('Support')
plt.ylabel('Confidence')
plt.colorbar(label='Lift')
plt.tight_layout()
plt.show()

# %%
basket_size = basket_sets.sum(axis=1)

# Trực quan hóa phân bố kích thước giỏ
plt.figure(figsize=(10, 5))
plt.hist(basket_size, bins=50, edgecolor='black')
plt.title('Distribution of quantity of items per cart')
plt.xlabel('Number of items')
plt.ylabel('Number of invoices')
plt.xlim(0, 50) # Giới hạn trục X để dễ nhìn hơn
plt.show()

print(f"Giỏ hàng trung bình có: {basket_size.mean():.2f} mặt hàng")
print(f"Giỏ hàng phổ biến nhất (median) có: {basket_size.median()} mặt hàng")
# Out:
# Giỏ hàng trung bình có: 20.68 mặt hàng
# Giỏ hàng phổ biến nhất (median) có: 15.0 mặt hàng

# %%
top_rules = rules.nlargest(20, 'lift')

# Chuyển đổi frozenset thành string để vẽ
ga = nx.DiGraph()
for _, row in top_rules.iterrows():
    antecedent = ', '.join(list(row['antecedents']))
    consequent = ', '.join(list(row['consequents']))
    ga.add_edge(antecedent, consequent, weight=row['lift'])

plt.figure(figsize=(12, 12))

pos = nx.spring_layout(ga, k=4, seed=42, iterations=100) 

nx.draw(ga, pos, with_labels=True, 
        node_size=1800,
        node_color='skyblue',
        font_size=8,
        font_weight='bold', 
        arrowsize=10)

plt.title('Network graph of the Top 20 rules (according to Lift)', size=16)
plt.show()

# %%
basket_sets_int = basket_sets.astype(int)

# Tính toán support của từng sản phẩm
item_support = basket_sets_int.sum(axis=0) / basket_sets_int.shape[0]

# Chọn Top 20 sản phẩm bán chạy nhất
topM = 20
top_products = item_support.sort_values(ascending=False).head(topM).index.tolist()

# --- Tạo ma trận con và ma trận đồng xuất hiện ---
sub_basket = basket_sets_int[top_products]
cooc_matrix = np.dot(sub_basket.T, sub_basket)
cooc_df = pd.DataFrame(cooc_matrix, index=top_products, columns=top_products)

# --- Vẽ Heatmap ---
plt.figure(figsize=(14, 12))
sns.heatmap(cooc_df, annot=True, fmt='d', cmap='viridis', annot_kws={"size": 8}) 
plt.title(f"Top {topM} Products Co-occurrence Heatmap", size=16)
plt.xlabel("Products", size=12)
plt.ylabel("Products", size=12)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()

# %%
#XÂY DỰNG HÀM GỢI Ý

def recommend_from_basket(cart_items, rules_df, top_k=5):
    """
    Gợi ý sản phẩm dựa trên các mặt hàng có trong giỏ.
    cart_items: list các tên sản phẩm trong giỏ
    rules_df: DataFrame các luật đã lọc
    top_k: Số lượng gợi ý
    """
    cart_set = set(cart_items)
    recommendations = {}
    
    # Duyệt qua các luật
    for _, row in rules_df.iterrows():
        antecedent_set = set(row['antecedents'])
        
        # Nếu sản phẩm trong luật (antecedent) nằm trong giỏ hàng
        if antecedent_set.issubset(cart_set):
            # Lấy các sản phẩm gợi ý (consequents)
            for item in row['consequents']:
                # Nếu sản phẩm gợi ý chưa có trong giỏ
                if item not in cart_set:
                    # Dùng 'confidence' làm điểm số ban đầu
                    if item not in recommendations:
                        recommendations[item] = row['confidence']
                    else:
                        # Nếu 1 sản phẩm được gợi ý bởi nhiều luật, ưu tiên luật có confidence cao
                        if row['confidence'] > recommendations[item]:
                            recommendations[item] = row['confidence']
                            
    # Sắp xếp các gợi ý theo 'confidence' giảm dần
    sorted_recommendations = sorted(recommendations.items(), key=lambda x: x[1], reverse=True)
    
    # Trả về top_k gợi ý hàng đầu
    return sorted_recommendations[:top_k]

# ----- VÍ DỤ SỬ DỤNG -----

# TH1: Khách hàng thêm "Tách trà hồng" vào giỏ
cart_1 = ['pink regency teacup and saucer']
suggestions_1 = recommend_from_basket(cart_1, rules)
print(f"Gợi ý cho giỏ hàng {cart_1}: \n {suggestions_1}\n")

# TH2: Khách hàng thêm cả "Tách trà hồng" VÀ "Tách trà hoa hồng"
cart_2 = ['pink regency teacup and saucer', 'roses regency teacup and saucer']
suggestions_2 = recommend_from_basket(cart_2, rules)
print(f"Gợi ý cho giỏ hàng {cart_2}: \n {suggestions_2}\n")
# Out:
# Gợi ý cho giỏ hàng ['pink regency teacup and saucer']:
#  [('green regency teacup and saucer', 0.8194726166328601), ('roses regency teacup and saucer', 0.7768762677484787), ('regency cakestand 3 tier', 0.5375253549695741)]
#
# Gợi ý cho giỏ hàng ['pink regency teacup and saucer', 'roses regency teacup and saucer']:
#  [('green regency teacup and saucer', 0.8903394255874674), ('regency cakestand 3 tier', 0.5874673629242819)]

# %%
# 4. XUẤT FILE CSV
# Cần chuyển đổi frozenset thành text trước khi lưu
rules_export = rules.copy()
rules_export['antecedents'] = rules_export['antecedents'].apply(lambda x: ', '.join(list(x)))
rules_export['consequents'] = rules_export['consequents'].apply(lambda x: ', '.join(list(x)))
#plt.title('Distribution of number of items per basket')
# Lưu file
rules_export.to_csv(r"..\association_rules_final.csv", index=False, encoding='utf-8-sig')
print("Đã xuất file 'association_rules_final.csv' thành công!")
# Out:
# Đã xuất file 'association_rules_final.csv' thành công!
